# %%
code =  r"""<!DOCTYPE html>
<html>
    <head>   
        <meta name="title" content="first web">
        <meta name="description" content="just for fun">
        <meta name="keywords" content="fun,first,web">
        <meta name="robots" content="index, follow">
        <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
        <meta name="language" content="English">  
        <!--
        SEO  
         -->
        <!-- Java script -->
        <script src="main.js">
            
        </script>
        
        <script>
            console.log("hello");
        </script>  
       
        <!-- css   js     html -->
        
        
        <!-- js CSS image title -->
                <title> Hello web</title>
        <!-- css code -->
        <style>
           body{
                background-color: rgb(240, 216, 31); 
                /* font-size: ; */
        }
            p{
                border: 2px black solid ;
            }
            span{
                border: 2px black solid ;
            }
            a:visited{
                color: brown;
            }
        </style>
       

    </head>
    <body>
        <span id="top">here i come</span>
        <del>12345</del>
        <p><strong><em>Lorem ipsum dolor sit amet consectetur adipisicing elit. Unde molestiae impedit animi perferendis ducimus provident eaque, cumque, in natus, nulla sed minus et iste voluptates consequuntur! Harum quo dolorum id.</em> ipsum dolor sit amet consectetur adipisicing elit. Nobis ad pariatur illo molestias non placeat earum explicabo sed, id, libero, obcaecati sequi mollitia fuga aliquid praesentium ut reiciendis ipsam eum.</strong></p>
        <p><b><i>Lorem ipsum dolor sit amet consectetur adipisicing elit. Vero mollitia, illo totam sapiente fuga nam, repellendus dicta rem sequi pariatur perspiciatis magni necessitatibus, voluptates enim officia eligendi cupiditate est? Pariatur?</i>Lorem ipsum dolor sit amet consectetur adipisicing elit. Ducimus fugit velit deserunt debitis quia neque quasi cupiditate accusamus quidem, laudantium voluptatum porro? Quis provident consequatur necessitatibus eligendi magni unde vel.</b></p>
        <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Perspiciatis sunt explicabo, eos minus laborum repellendus reiciendis eum corrupti. Maxime iusto laudantium velit cumque culpa, facilis perspiciatis quas tenetur explicabo quasi.</p>
        <h1><u>Hello here</u> hello world 1</h1>
        <h2>hello world 2</h2>
        <h3>hello world 3</h3>
        <h4>hello world 4</h4>
        <h5>hello world 5</h5>
        <h6>hello world 6</h6>
        <br>
        hello
        <a href="#top" target="_self"><img width="100px" src="C:\Users\admin\OneDrive\Pictures\random cat.jpg" alt=""></a>  hyper text markup language
        <a href="https://google.com">Click here to visit google</a>  hyper text markup language
        <a href="https://wikipidea.com">Click here to visit google</a>  hyper text markup language
        <dl>
            <dt>Python</dt>
            <dd>Lorem ipsum dolor sit amet consectetur adipisicing elit. Obcaecati, officiis eaque asperiores temporibus accusantium placeat, sapiente eos consequatur rerum at et sit cum aspernatur corporis voluptatum enim architecto? Iure, cum?</dd>
            <dt>Java</dt>
            <dd>Lorem ipsum dolor sit amet consectetur adipisicing elit. Eveniet earum voluptates distinctio, animi voluptate, modi corrupti illo, ratione ipsam deleniti quam. Ratione magni laborum, quod exercitationem distinctio porro saepe. Cum?</dd>
        </dl>
        <ol type="a" start="100">
            <!-- a A i I 1 -->
            <li>hello1</li>  li*5{hello $}
            <li>hello2</li>
            <li>hello3</li>
            <li>hello4</li>
        </ol>
        <ul type="square">
            <!-- circle square disc -->
            <li>hello1</li>
            <li>hello2</li>
            <li>hello3</li>
            <li>hello4</li>
        </ul>


        <p> The p tag Lorem ipsum dolor sit, &lt;hello&gt;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     amet consectetur adipisicing elit. Error similique aliquid non quas. Sunt aut cumque expedita hic architecto nobis, laborum a perspiciatis, vel mollitia similique enim, quasi voluptates doloribus.</p>
        <p> The p tag again </p>
        <span>The span</span>
        <br>
        <hr>
        <span>The span again Lorem ipsum dolor sit amet consectetur adipisicing elit. Voluptatem saepe commodi numquam exercitationem illo eius accusantium aspernatur, explicabo debitis neque, temporibus esse nobis ipsa? Quasi distinctio qui dolorum dolor expedita.</span>
        <br>
        <br><br><br>
        <pre>
            Lorem ipsum dolor sit amet consectetur,<br> adipisicing elit. Maiores cumque, temporibus totam consectetur quos esse voluptates ea, dolore ipsum dignissimos asperiores, repudiandae quibusdam eius unde? Laborum delectus debitis possimus culpa.
                Lorem ipsum, dolor sit amet consectetur 
                    adipisicing elit. Tenetur, quod eveniet, 
                    porro nemo enim optio, 
                  
                dolore tempore saepe nam ipsum maxime rerum quibusdam vel quas magni. Iste recusandae error saepe.
        </pre>
        <!-- 0 1 -->
        <a href=""></a>
        <!-- <video loop width="100%" height="800px%"  src="C:\Users\admin\Downloads\12976407_2160_3840_30fps.mp4" muted controls ></video> -->
        <!-- <audio src="C:\Users\admin\Downloads\25f8aa80e4d69e9d017c43b8b7e989a3_96.m4a" muted  autoplay controls loop ></audio> -->
        <video width="400px" height="" src="C:\Users\admin\Downloads\12976407_2160_3840_30fps.mp4" controls></video>
        <!-- <iframe width="100%" height="600px" src="https://www.youtube.com/embed/77vRyWNqZjM?si=sjwdhVecXOVyLq8Z" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe> -->
        <!-- <iframe src="https://www.google.com/maps/embed?pb=!1m14!1m12!1m3!1d171.4918972878711!2d72.85263387245156!3d19.11844904143444!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!5e1!3m2!1sen!2sin!4v1737969569375!5m2!1sen!2sin" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe> -->
        <!-- <img src="C:\Users\admin\OneDrive\Pictures\random cat.jpg" alt="the cat image"> -->
    </body>
</html>"""

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(code, 'lxml')

# %%
print(bs.title,
      bs.title.name,
      sep = '\n')
# Out:
# <title> Hello web</title>
# title

# %%
print(bs.p,
      bs.p.text,
      bs.strong,
      sep = '\n')
# Out:
# <p><strong><em>Lorem ipsum dolor sit amet consectetur adipisicing elit. Unde molestiae impedit animi perferendis ducimus provident eaque, cumque, in natus, nulla sed minus et iste voluptates consequuntur! Harum quo dolorum id.</em> ipsum dolor sit amet consectetur adipisicing elit. Nobis ad pariatur illo molestias non placeat earum explicabo sed, id, libero, obcaecati sequi mollitia fuga aliquid praesentium ut reiciendis ipsam eum.</strong></p>
# Lorem ipsum dolor sit amet consectetur adipisicing elit. Unde molestiae impedit animi perferendis ducimus provident eaque, cumque, in natus, nulla sed minus et iste voluptates consequuntur! Harum quo dolorum id. ipsum dolor sit amet consectetur adipisicing elit. Nobis ad pariatur illo molestias non placeat earum explicabo sed, id, libero, obcaecati sequi mollitia fuga aliquid praesentium ut reiciendis ipsam eum.
# <strong><em>Lorem ipsum dolor sit amet consectetur adipisicing elit. Unde molestiae impedit animi perferendis ducimus provident eaque, cumque, in natus, nulla sed minus et iste voluptates consequuntur! Harum quo dolorum id.</em> ipsum dolor sit amet consectetur adipisicing elit. Nobis ad pariatur illo molestias non placeat earum explicabo sed, id, libero, obcaecati sequi mollitia fuga aliquid praesentium ut reiciendis ipsam eum.</strong>

# %%
import requests

request = requests.get('https://www.flipkart.com/search?q=samsung galaxy tab')
print(request.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup

cls = 'KzDlHZ'
soup = BeautifulSoup(request.text, 'lxml')

result = soup.find_all(class_=cls)

# %%
for i in result:
    print(i.text)
# Out:
# Samsung Galaxy Tab A9+ 8 GB RAM 128 GB ROM 11.0 inch with Wi-Fi+5G Tablet (Graphite)
# Samsung Galaxy Tab S9 FE+ 8 GB RAM 128 GB ROM 12.4 Inch with Wi-Fi Only Tablet (Gray)
# Samsung Galaxy Tab A9+ 8 GB RAM 128 GB ROM 11.0 inch with Wi-Fi+5G Tablet (Navy)
# Samsung Galaxy Tab S9 FE 6 GB RAM 128 GB ROM 10.9 inch with Wi-Fi Only Tablet (Gray)
# Samsung Galaxy Tab S9 FE+ 8 GB RAM 128 GB ROM 12.4 Inch with Wi-Fi Only Tablet (Silver)
# Samsung Galaxy Tab S9 FE+ 8 GB RAM 128 GB ROM 12.4 Inch with Wi-Fi Only Tablet (Lavender)
# Samsung Galaxy Tab A9+ 8 GB RAM 128 GB ROM 11.0 inch with Wi-Fi+5G Tablet (Silver)
# Samsung Galaxy Tab A9 4 GB RAM 64 GB ROM 8.7 Inch with 4G Tablet (Graphite)
# Samsung Galaxy Tab A9+ 8 GB RAM 128 GB ROM 11.0 inch with Wi-Fi Only Tablet (Graphite)
# Samsung Galaxy Tab A9+ 4 GB RAM 64 GB ROM 11.0 inch with Wi-Fi+5G Tablet (Graphite)
# Samsung Galaxy Tab A8 3 GB RAM 32 GB ROM 10.5 inch with 4G Tablet (Gray)
# Samsung Galaxy Tab S9 FE+ 12 GB RAM 256 GB ROM 12.4 Inch with Wi-Fi Only Tablet (Gray)
# Samsung Galaxy Tab A9+ 4 GB RAM 64 GB ROM 11.0 inch with Wi-Fi Only Tablet (Silver)
# Samsung Galaxy Tab S9 FE+ 12 GB RAM 256 GB ROM 12.4 Inch with Wi-Fi Only Tablet (Mint)
# Samsung Galaxy Tab S9 8 GB RAM 128 GB ROM 11.0 Inch with Wi-Fi Only Tablet (Graphite)
# Samsung Galaxy Tab A8 4 GB RAM 64 GB ROM 10.5 inch with 4G Tablet (Gray)
# Samsung Galaxy Tab A11 8 GB RAM 128 GB ROM 8.7 inch with Wi-Fi Only Gaming Tablet (Gray)
# Samsung Galaxy Tab A9+ 4 GB RAM 64 GB ROM 11.0 inch with Wi-Fi Only Tablet (GRAPHITE)
# Samsung Galaxy Tab S10 Ultra 12 GB RAM 256 GB ROM 14.6 inch with Wi-Fi Only Gaming Tablet (Moonstone G...
# Samsung Galaxy Tab S9 FE 6 GB RAM 128 GB ROM 10.9 inch with Wi-Fi+5G Tablet (Gray)
# Samsung Galaxy Tab S9 FE 6 GB RAM 128 GB ROM 10.9 inch with Wi-Fi Only Tablet (Mint)
# Samsung Galaxy Tab S9 FE+ 8 GB RAM 128 GB ROM 12.4 Inch with Wi-Fi+5G Tablet (Gray)
# Samsung Galaxy Tab S9 FE 8 GB RAM 256 GB ROM 10.9 inch with Wi-Fi Only Tablet (Silver)
# Samsung Galaxy Tab S9 FE 8 GB RAM 256 GB ROM 10.9 inch with Wi-Fi Only Tablet (Gray)

# %%
import requests

url = "https://www.amazon.in/s?k=samsung&rh=n%3A1389401031&ref=nb_sb_noss"  # Example product URL

# Headers mimic a real browser to reduce chances of blocking
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/129.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)
print(response.text[:1000])  # Print first 1000 characters of the HTML
# Out:
# Status Code: 200
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
#
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">
# <link rel="dns-prefetch" href="https://m.media-amazon.com">
# <link rel="dns-prefetch" href="https://completion.amazon.com">
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function

# %%
from bs4 import BeautifulSoup

code = '' # there was a huge ass html code here. use your own code from any website using the inspect tab.
soup = BeautifulSoup(code, 'lxml')
data = soup.select('a>h2>span') # update the tags according to your requirements.

for d in data:
    print(d.text)

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

df = pd.DataFrame()

with open('files/HTML/amazon_samsung.html', encoding = 'UTF-8') as file:
    soup = BeautifulSoup(file.read(), 'lxml')
    data = soup.select('a>h2>span')

    entry = []
    for i in data:
        entry.append(i.text)
    
    df['title'] = entry

with open('files/HTML/amazon_samsung.html', encoding = 'UTF-8') as file:
    soup = BeautifulSoup(file.read(), 'lxml')
    data = soup.select('a>h2>span')
    price = []

    for i in data:
        p = i.parent.parent.parent.next_sibling.next_sibling.find(class_ = 'a-offscreen')
        if p:
            price.append(p.text.replace(',', "_").replace('₹', ''))
    
    df['price'] = price

with open('files/HTML/amazon_samsung.html', encoding = 'UTF-8') as file:
    image = []
    alt = []
    soup = BeautifulSoup(file.read(), 'lxml')
    data = soup.find_all('img', class_ = 's-image')
    for i in data:
        image.append((i.attrs.get('src')))
        alt.append((i.attrs.get('alt')))
    
    df['image'] = image
    df['alt_image_txt'] = alt

with open('files/HTML/amazon_samsung.html', encoding = 'UTF-8') as file:
    soup = BeautifulSoup(file.read(), 'lxml')

    for i, alt in zip(df['image'], df['alt_image_txt']):
        response = requests.get(i)
        try:
            with open(fr'files/image/products/{alt[:30]}.jpg', 'wb') as f:

# %%
data = soup.find_all('img', class_ = 's-image')

for i in data:
    print(i.attrs.get('alt'))
# Out:
# Sponsored Ad - Samsung Galaxy M36 5G (Velvet Black, 6 GB RAM, 128 GB Storage)| Circle to Search| Google Gemini| Corning Go...
# Samsung Galaxy M07 (Black, 4GB RAM, 64GB Storage) | MediaTek Helio G99 | IP54 Rating | 50MP Auto Focus Camera | 7.6mm Slim...
# Samsung Galaxy S24 FE 5G AI Smartphone (Graphite, 8GB RAM, 128GB Storage)
# Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands| 25...
# Sponsored Ad - Spigen Liquid Air for Samsung Galaxy S24 Ultra Case, Galaxy S24 Ultra Back Cover (2024) - TPU｜Marble Gray
# Sponsored Ad - Spigen Thin Fit Pro for Samsung Galaxy Z Flip 5 Case, Transparent Galaxy Z Flip5 Back Cover (2023) - TPU+Po...
# Sponsored Ad - Spigen Rugged Armor for Samsung Galaxy S24 Ultra Case, Galaxy S24 Ultra Back Cover (2024) - TPU｜Matte Black
# Sponsored Ad - ShieldTech® TPU Back Cover Case + Tempered Glass for Samsung Galaxy F17 5G | Transparent Mobile Phone Back ...
# Sponsored Ad - REALCASE for Samsung Galaxy A36 5G | Magnetic Clear Case | Durable, Scratch-Resistant | Slim Transparent Co...
# Samsung Galaxy A35 5G (Awesome Navy, 8GB RAM, 128GB Storage) Without Offer
# Samsung Galaxy M17 5G (Sapphire Black, 4GB RAM, 128GB Storage)| 50MP OIS Triple Camera| Gorilla Glass Victus| IP54 Rating|...
# Samsung Galaxy A55 5G (Awesome Iceblue, 8GB RAM, 256GB Storage) | AI | Metal Frame | 50 MP Main Camera (OIS) | Super HDR V...
# Samsung Galaxy A35 5G (Awesome Iceblue, 8GB RAM, 128GB Storage) Without Offer
# Samsung Galaxy A56 5G (Awesome Olive, 8GB, 256GB) | Metal Frame | Gemini Live | Awesome Intelligence (AI): Circle to Searc...
# Samsung Galaxy A55 5G (Awesome Navy, 8GB RAM, 256GB Storage) | AI | Metal Frame | 50 MP Main Camera (OIS) | Super HDR Vide...
# Samsung Galaxy M35 5G (DayBreak Blue,8GB RAM,128GB Storage)| Corning Gorilla Glass Victus+| AnTuTu Score 595K+| Vapour Coo...
# Samsung Galaxy M06 5G (Sage Green, 6GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands| ...
# Samsung Galaxy A55 5G (Awesome Iceblue, 8GB RAM, 128GB Storage) | AI | Metal Frame | 50 MP Main Camera (OIS) | Super HDR V...
# Samsung Galaxy A55 5G (Awesome Navy, 8GB RAM, 128GB Storage) | AI | Metal Frame | 50 MP Main Camera (OIS) | Super HDR Vide...
# Samsung Galaxy A55 5G (Awesome Iceblue, 12GB RAM, 256GB Storage) | AI | Metal Frame | 50 MP Main Camera (OIS) | Super HDR ...
# Samsung Galaxy M36 5G (Serene Green, 8 GB RAM, 128 GB Storage)| Circle to Search| Google Gemini| Corning Gorilla Glass Vic...
# Samsung Galaxy S24 FE 5G AI Smartphone (Mint, 8GB RAM, 128GB Storage)
# Samsung Original 25W Type-C Travel Adaptor Without Cable, White
# Samsung Galaxy M06 5G (Blazing Black, 4GB RAM, 64GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands...
# Samsung Galaxy M06 5G (Blazing Black, 6GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Band...
# Samsung Galaxy S24 FE 5G (Mint, 8GB RAM+ 256GB Storage) | Exynos 2400e Processor | Dynamic AMOLED Display | Dual Nano-SIM...
# Samsung Galaxy S24 5G AI Smartphone (Marble Gray, 8GB, 128GB Storage)
# Samsung Galaxy A35 5G (Awesome Lilac, 8GB RAM, 128GB Storage) | Premium Glass Back | 50 MP Main Camera (OIS) | Nightograph...
# Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB Storage) | 50MP Dual Camera | Bigger 6.7" HD+ Display | 5000mAh Battery | 2...
# Samsung Galaxy S24 5G AI Smartphone (Onyx Black, 8GB, 256GB Storage)
# Sponsored Ad - Spigen Tough Armor for Samsung Galaxy S24 Ultra Case, Galaxy S24 Ultra Back Cover (2024) - TPU+Poly Carbona...
# Sponsored Ad - Spigen Liquid Air for Samsung Galaxy S24 Ultra Case, Galaxy S24 Ultra Back Cover (2024) - TPU｜Abyss Green
# Sponsored Ad - Spigen Rugged Armor for Samsung Galaxy S24 Ultra Case, Galaxy S24 Ultra Back Cover (2024) - TPU｜Matte Black
# Sponsored Ad - FEDUS 65W Gan Charger, Fast Charger Gan Adapter Type C & USB Port Charging Wall for Laptop, Phone, Samsung,...
# Sponsored Ad - Ambrane 30W Dual Port GaN Charger, USB & Type C Fast Charging Adapter For iPhone 16/15/14/13/12/11 (Pro,Pro...

# %%
df.head()
# Out:
#                                                title   price  \
# 0  Samsung Galaxy M36 5G (Velvet Black, 6 GB RAM,...  13_999
# 1  Samsung Galaxy M07 (Black, 4GB RAM, 64GB Stora...   6_799
# 2  Samsung Galaxy S24 FE 5G AI Smartphone (Graphi...  34_980
# 3  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...   7_499
# 4  Spigen Liquid Air for Samsung Galaxy S24 Ultra...   1_199
#
#                                                image
# 0  https://m.media-amazon.com/images/I/61FcXMhjr8...
# 1  https://m.media-amazon.com/images/I/610lbucItm...
# 2  https://m.media-amazon.com/images/I/71eUNTW+nJ...
# 3  https://m.media-amazon.com/images/I/71evPv-Tvm...
# 4  https://m.media-amazon.com/images/I/71ieLFH4ws...
